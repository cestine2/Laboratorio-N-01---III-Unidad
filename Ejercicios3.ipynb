# %% [markdown]
# ## Data Import and export

# %%
import numpy as np
import pandas as pd

# %%
# save to csv
example = pd.DataFrame({'user': ['K0', 'K0', 'K1', 'K2'],
                     'month': [1, 2, 1, 2],
                        'purchase': [100, 125, 133, 230]})
example.to_csv('example.csv', index=False)

# %% [markdown]
# ## CSV
#
# ### CSV Input

# %%
df = pd.read_csv('example.csv')
df
# Out:
#    month  purchase user
# 0      1       100   K0
# 1      2       125   K0
# 2      1       133   K1
# 3      2       230   K2

# %% [markdown]
# ### CSV Output

# %%
df['company'] = 'Pepe' 
df.to_csv('example.txt', sep=';', index=False)

# %% [markdown]
# ## Excel
# Pandas can read and write excel files, keep in mind, this only imports data. Not formulas or images, having images or macros may cause this read_excel method to crash.

# %% [markdown]
# ### Excel Input

# %%
# IMPORT ONE OF YOUR XLS FILES
pd.read_excel('Excel_Sample.xlsx',sheetname='Sheet1')

# %% [markdown]
# ### Excel Output

# %%
df.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')
